# %% [markdown]
# # <center> 46. Permutations </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/permutations/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# A permutation is the rearrangement of the elements. The total number of permutations for n elements is n!
#
# Use backtracking and swapping to explore all permutations and rearrange the elements.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set n = total number of elements
# - create a result list to store the permutations
# - define a helper function for backtracking <br>
# backtrack(start index)
#     - if current start index is same as n, we have considered all elements and current rearrangement/permutation is valid
#         - add a copy of the current permutation to the result list and return
#             - *(add the copy to avoid overwriting during future backtracking)*
#     - for each index in the range start index to last index in the input list
#         - swap the start index and current index element
#         - backtrack
#         - swap the start index and current index element again
# - start backtracking from index 0 as the start position
# - return the result list
#
#
# ## Complexity
# - Time complexity: O(copy * generating permutations) → O(permutaion size * recursion breadth) → O(n * n!)
#     - *we will consider the time complexity of copy() here because an array of size has n! permutations and we are copying each permutation to add to our result*
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
#
#
# - Space complexity: O(recursion stack + result list) → O(recursion depth/levels + total permutations * permutation size)  → O(n + n! * n) → O(n * n!)
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
#
#
# ## Code

# %%
class Solution:

    def permute(self, nums: List[int]) -> List[List[int]]:
        n = len(nums)
        res = []

        def backtrack(start: int) -> None:
            if start == n:
                res.append(nums.copy())
                return
            for i in range(start, n):
                nums[start], nums[i] = nums[i], nums[start]
                backtrack(start + 1)
                nums[start], nums[i] = nums[i], nums[start]

        backtrack(0)
        return res
