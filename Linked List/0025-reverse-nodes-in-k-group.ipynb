# %% [markdown]
# # <center> 25. Reverse Nodes in k-Group </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/reverse-nodes-in-k-group/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# Find the total number of groups and reverse each group.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - check base cases
#   - if k is 1, return because the result after reversing will be the same as the original list
# - create a dummy node and point it to the head
# - set current node pointer cur = head
# - set previous node pointer prev = dummy
# - set n = 0 to find the length of the list (i.e total nodes)
# - loop until the last node
#   - increment n
#   - update cur move to the next node
# - reset cur to point to the head node
# - find total number of groups i.e n/k and loop <br>
# for each group
#     - loop k times to reverse the k-nodes sublist using prev, cur, and next pointers
#     - update prev and cur to move to the next group
# - return dummy.next as head of the modified list
#
#
# ## Complexity
# - Time complexity: O(finding list size + loops to reverse groups)  → O(n + n/k * k) → O(n)
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
#
# - Space complexity: O(total new nodes created) → O(1) → O(1)
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
#
#
# ## Code

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next


class Solution:

    def reverseKGroup(self, head: Optional[ListNode], k: int) -> Optional[ListNode]:
        if k == 1:
            return head
        dummy = ListNode(0, head)
        cur = head
        prev = dummy
        n = 0
        while cur:
            n += 1
            cur = cur.next
        cur = head
        for _ in range(n // k):
            for _ in range(k - 1):
                next = cur.next
                cur.next = next.next
                next.next = prev.next
                prev.next = next
            prev = cur
            cur = cur.next
        return dummy.next
