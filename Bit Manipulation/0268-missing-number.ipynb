# %% [markdown]
# # <center> 268. Missing Number </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/missing-number/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# missing number in range 1 to n = sum of all numbers in range 1 to n - input array sum
#
# The sum of first n natural numbers i.e numbers in the range 1 to n is n(n+1)/2
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set n = size of the input array
# - find the actual sum and input array sum, find their difference, and return the result
#
#
# ## Complexity
# - Time complexity: O(finding input array sum) → O(n)
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
#
# - Space complexity: O(1)
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
#
#
# ## Code

# %%
class Solution:

    def missingNumber(self, nums: List[int]) -> int:
        n = len(nums)
        return n * (n + 1) // 2 - sum(nums)
